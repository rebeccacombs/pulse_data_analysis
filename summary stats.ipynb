# %%
import pandas as pd

# %%
df = pd.read_csv('Wellbeing Questionnaire csv.csv')

# %%
df
# Out:
#          Net ID  How many younger siblings do you have?  \
# 0         hcc18                                       2
# 1         na202                                       2
# 2          ick8                                       1
# 3         xl368                                       1
# 4          zg95                                       1
# 5         zc198                                       0
# 6         sd505                                       0
# 7         hg141                                       0
# 8         jy332                                       0
# 9         cc823                                       0
# 10        hp147                                       0
# 11        rk326                                       0
# 12         wg87                                       0
# 13  Yuxiang Lin                                       0
# 14        rrb53                                       1
# 15        rdd33                                       0
# ...

# %%
df['How would you rank your overall wellbeing right now on a scale from 1-10?'].describe()
# Out:
# count    21.000000
# mean      6.238095
# std       1.946915
# min       1.000000
# 25%       6.000000
# 50%       7.000000
# 75%       7.000000
# max       9.000000
# Name: How would you rank your overall wellbeing right now on a scale from 1-10?, dtype: float64
